# %% [markdown]
# <h1>Introduction to regression</h1>
# In this notebook we will have an overview of regression and how scikit-learn can be used to regress data.

# %%
# Importing the holy trinity of data science.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# getting seaborn online to give our graphics a kick.
import seaborn as sns
sns.set()

# %% [markdown]
# First, let us work towards building an intuition of the problem at hand by considering the dataset ds1 below,

# %%
ds1 = [0,1,2,3,4,5,6]
plt.plot(ds1, marker='*',linestyle='')

# %% [markdown]
# Assuming that the red dot in the plot is a continuation of the dataset ds1 how can you workout the continuation of the this sequence?

# %%
plt.plot(ds1, marker='*',linestyle='')
plt.scatter(np.arange(7,10),np.arange(7, 10),c='r')

# %% [markdown]
# Linear equations take the shape:
#
# $$ Y = aX+b$$
#
# From this, all we need is two points to workout the coefficient $$a$$ and knowing the value of $$Y(X=0)$$ to obtain B.

# %% [markdown]
# Question, would this logic work for the dataset plotted below?

# %%
ds2 = [x**2 for x in range(10)]
plt.plot(ds2, marker='*',linestyle='')

# %%
del ds1,ds2

# %% [markdown]
# Now let us import our dataset.

# %%
df = pd.read_csv('Datasets/ds_salaries.csv',sep=',',index_col=0)

# %%
df.keys()
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %% [markdown]
# Exercises:
#
# - what would you consider an average, low and high salary for data scientist worldwide and in GB?
#
# - Can you make a graphic containing the distribution of these salaries?
#
# - Compare the salaries of DSs that work at the office, hybrid or remote.

# %%
df.salary_in_usd.describe()
# Out:
# count       607.000000
# mean     112297.869852
# std       70957.259411
# min        2859.000000
# 25%       62726.000000
# 50%      101570.000000
# 75%      150000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %%
df[df.company_location == 'GB'].salary_in_usd.describe()
# Out:
# count        47.000000
# mean      81583.042553
# std       29524.011146
# min       37300.000000
# 25%       57575.000000
# 50%       78526.000000
# 75%      103931.000000
# max      183228.000000
# Name: salary_in_usd, dtype: float64

# %%
df.boxplot(column='salary_in_usd')
# Out:
# <Axes: >

# %%
df.boxplot(column='salary_in_usd')
# Out:
# <Axes: >

# %%
df.salary_in_usd.describe()
# Out:
# count       607.000000
# mean     112297.869852
# std       70957.259411
# min        2859.000000
# 25%       62726.000000
# 50%      101570.000000
# 75%      150000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %%
df.keys()
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
len(df)
# Out:
# 607

# %%
df.company_location.value_counts()
# Out:
# company_location
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: count, dtype: int64

# %%
df[df.company_location == 'US'].salary_in_usd.describe()
# Out:
# count       355.000000
# mean     144055.261972
# std       69906.895041
# min        5679.000000
# 25%      100000.000000
# 50%      135000.000000
# 75%      170000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %%
df[df.company_location == 'GB'].salary_in_usd.describe()
# Out:
# count        47.000000
# mean      81583.042553
# std       29524.011146
# min       37300.000000
# 25%       57575.000000
# 50%       78526.000000
# 75%      103931.000000
# max      183228.000000
# Name: salary_in_usd, dtype: float64

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df[df.company_location != df.employee_residence]
# Out:
#      work_year experience_level employment_type  \
# 17        2020               SE              FT
# 19        2020               MI              FT
# 32        2020               SE              FT
# 40        2020               MI              FT
# 53        2020               EN              FT
# 54        2020               SE              FL
# 61        2020               MI              FT
# 70        2020               MI              FT
# 73        2021               EX              FT
# 82        2021               MI              FT
# 84        2021               EX              FT
# 89        2021               SE              FT
# 90        2021               SE              FT
# 96        2021               EN              PT
# 99        2021               MI              FT
# 102       2021               MI              FT
# 113       2021               EN              PT
# 120       2021               MI              FT
# 132       2021               MI              FT
# 149       2021               SE              FT
# 156       2021               MI              FT
# 179       2021               MI              FT
# 182       2021               MI              FT
# 186       2021               SE              FT
# 187       2021               EX              FT
# 188       2021               SE              FT
# 190       2021               SE              FT
# 198       2021               SE              FT
# 200       2021               MI              FT
# 203       2021               SE              FT
# 208       2021               MI              FL
# 212       2021               MI              FT
# 213       2021               EN              FT
# 224       2021               SE              FT
# 244       2021               EN              FT
# 264       2021               MI              FT
# 265       2021               SE              FT
# 273       2021               EN              FT
# 281       2021               EN              FT
# 396       2022               MI              FT
# 417       2022               SE              FT
# 488       2022               MI              FL
# 489       2022               EN              CT
# 490       2022               SE              FT
# 494       2022               SE              FT
# 496       2022               EN              FT
# 502       2022               EN              FT
# 506       2022               MI              FT
# 515       2022               MI              FT
# 521       2022               EN              FT
# 606       2022               MI              FT
#
#                               job_title    salary salary_currency  \
# 17                    Big Data Engineer    100000             EUR
# 19                   Lead Data Engineer     56000             USD
# 32                       Data Scientist     60000             EUR
# 40                       Data Scientist     45760             USD
# 53                        Data Engineer     48000             EUR
# 54             Computer Vision Engineer     60000             USD
# 61                        Data Engineer    130800             USD
# 70                       Data Scientist     55000             EUR
# 73                      BI Data Analyst    150000             USD
# 82               Applied Data Scientist     68000             CAD
# 84             Director of Data Science    130000             EUR
# 89                         Data Analyst     80000             USD
# 90               Marketing Data Analyst     75000             EUR
# 96                         AI Scientist     12000             USD
# 99    Computer Vision Software Engineer     81000             EUR
# 102                     BI Data Analyst  11000000             HUF
# 113                        AI Scientist     12000             USD
# 120                   Big Data Engineer     60000             USD
# 132  Applied Machine Learning Scientist     38400             USD
# 149                 Cloud Data Engineer    160000             USD
# 156                      Data Scientist    160000             SGD
# 179                      Data Scientist    420000             INR
# 182                       Data Engineer     22000             EUR
# 186             Data Analytics Engineer     50000             USD
# 187             Data Science Consultant     59000             EUR
# 188                       Data Engineer     65000             EUR
# 190                Data Science Manager    152000             USD
# 198                Data Science Manager   4000000             INR
# 200                      Data Scientist     52000             EUR
# 203                  Research Scientist     50000             USD
# 208                       Data Engineer     20000             USD
# 212                       Data Engineer     48000             GBP
# 213                   Big Data Engineer    435000             INR
# 224          Machine Learning Scientist    225000             USD
# 244                        AI Scientist   1335000             INR
# 264                      Data Scientist     21600             EUR
# 265                  Lead Data Engineer    160000             USD
# 273           Machine Learning Engineer     85000             USD
# 281                  Research Scientist    100000             USD
# 396           Machine Learning Engineer     80000             EUR
# 417               Data Science Engineer     60000             USD
# 488                      Data Scientist    100000             USD
# 489  Applied Machine Learning Scientist     29000             EUR
# 490                        Head of Data    200000             USD
# 494                      Data Scientist    100000             USD
# 496                       Data Engineer     52800             EUR
# 502                      Data Scientist     40000             USD
# 506  Applied Machine Learning Scientist     75000             USD
# 515                      Data Scientist     48000             USD
# 521            Computer Vision Engineer     10000             USD
# 606                        AI Scientist    200000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 17          114047                 PL           100               GB
# 19           56000                 PT           100               US
# 32           68428                 GR           100               US
# 40           45760                 PH           100               US
# 53           54742                 PK           100               DE
# 54           60000                 RU           100               US
# 61          130800                 ES           100               US
# 70           62726                 FR            50               LU
# 73          150000                 IN           100               US
# 82           54238                 GB            50               CA
# 84          153667                 IT           100               PL
# 89           80000                 BG           100               US
# 90           88654                 GR           100               DK
# 96           12000                 BR           100               US
# 99           95746                 DE           100               US
# 102          36259                 HU            50               US
# 113          12000                 PK           100               US
# 120          60000                 ES            50               RO
# 132          38400                 VN           100               US
# 149         160000                 BR           100               US
# 156         119059                 SG           100               IL
# 179           5679                 IN           100               US
# 182          26005                 RO             0               US
# 186          50000                 VN           100               GB
# 187          69741                 FR           100               ES
# 188          76833                 RO            50               GB
# 190         152000                 US           100               FR
# 198          54094                 IN            50               US
# 200          61467                 DE            50               AT
# 203          50000                 FR           100               US
# 208          20000                 IT             0               US
# 212          66022                 HK            50               GB
# 213           5882                 IN             0               CH
# 224         225000                 US           100               CA
# 244          18053                 IN           100               AS
# 264          25532                 RS           100               DE
# 265         160000                 PR            50               US
# 273          85000                 NL           100               DE
# 281         100000                 JE             0               CN
# 396          87932                 FR           100               DE
# 417          60000                 AR           100               MX
# 488         100000                 CA           100               US
# 489          31875                 TN           100               CZ
# 490         200000                 MY           100               US
# 494         100000                 BR           100               US
# 496          58035                 PK           100               DE
# 502          40000                 JP           100               MY
# 506          75000                 BO           100               US
# 515          48000                 RU           100               US
# 521          10000                 PT           100               LU
# 606         200000                 IN           100               US
#
#     company_size
# 17             S
# 19             M
# 32             L
# 40             S
# 53             L
# 54             S
# 61             M
# 70             S
# 73             L
# 82             L
# 84             L
# 89             S
# 90             L
# 96             S
# 99             S
# 102            L
# 113            M
# 120            M
# 132            M
# 149            S
# 156            M
# 179            S
# 182            L
# 186            M
# 187            S
# 188            S
# 190            L
# 198            L
# 200            M
# 203            S
# 208            L
# 212            S
# 213            L
# 224            L
# 244            S
# 264            S
# 265            S
# 273            S
# 281            L
# 396            M
# 417            L
# 488            M
# 489            M
# 490            M
# 494            M
# 496            M
# 502            L
# 506            L
# 515            S
# 521            M
# 606            L

# %%
len(df)
# Out:
# 607

# %%
df.salary_in_usd.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column='salary_in_usd')
# Out:
# <Axes: >

# %%
df.company_location.value_counts()
# Out:
# company_location
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: count, dtype: int64

# %%
len(df[df.company_location != df.employee_residence])
# Out:
# 51

# %%
df[df['remote_ratio'] >50 ].salary_in_usd.describe()
# Out:
# count       381.000000
# mean     122457.454068
# std       72710.843718
# min        4000.000000
# 25%       75774.000000
# 50%      115000.000000
# 75%      160000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %%
df[df['remote_ratio'] <=50 ].salary_in_usd.describe()
# Out:
# count       226.000000
# mean      95170.429204
# std       64516.566450
# min        2859.000000
# 25%       54130.000000
# 50%       82636.000000
# 75%      121759.500000
# max      450000.000000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# <h1>Data prep</h1>
# Now we will prepare the data to be fed into the machine learning models.
#
# Exercise: are there any columns that should be excluded?

# %%
df.work_year.value_counts()
# Out:
# work_year
# 2022    318
# 2021    217
# 2020     72
# Name: count, dtype: int64

# %%
df.employment_type.value_counts()
# Out:
# employment_type
# FT    588
# PT     10
# CT      5
# FL      4
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df = df.drop(['salary','salary_currency'],axis=1)

# %% [markdown]
# Exercise: is there any missing data that needs to be dealt with? (if so, do it!)

# %%
print('no.')
# Out:
# no.

# %%
df.job_title.unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
#        'Principal Data Engineer', 'Machine Learning Developer',
#        'Applied Machine Learning Scientist', 'Data Analytics Manager',
#        'Head of Data Science', 'Data Specialist', 'Data Architect',
#        'Finance Data Analyst', 'Principal Data Analyst',
#        'Big Data Architect', 'Staff Data Scientist', 'Analytics Engineer',
#        'ETL Developer', 'Head of Machine Learning', 'NLP Engineer',
#        'Lead Machine Learning Engineer', 'Data Analytics Lead'],
#       dtype=object)

# %% [markdown]
# Exercise: find what columns should be encoded and encode them.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/olivertozer/anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/olivertozer/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/olivertozer/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/olivertozer/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/olivertozer/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Hint, use:
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833                 DE             0               DE
# 1         260000                 JP             0               JP
# 2         109024                 GB            50               GB
# 3          20000                 HN             0               HN
# 4         150000                 US            50               US
#
#   company_size
# 0            L
# 1            S
# 2            M
# 3            S
# 4            L

# %%
df.key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/96/hkcg5jn533j7q4c_v0c38w0h0000gn/T/ipykernel_20251/1225380035.py in ?()
# ----> 1 df.key()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'key'

# %%
le = LabelEncoder()

# %%
le.fit_transform(df.experience_level)
# Out:
# array([2, 3, 3, 2, 3, 0, 3, 2, 2, 3, 0, 2, 0, 2, 2, 2, 0, 3, 0, 2, 2, 2,
#        3, 2, 2, 1, 0, 3, 0, 3, 2, 0, 3, 2, 2, 2, 2, 0, 0, 0, 2, 1, 2, 2,
#        2, 0, 2, 3, 2, 2, 0, 0, 0, 0, 3, 3, 2, 2, 3, 2, 2, 2, 0, 3, 3, 0,
#        0, 3, 0, 3, 2, 2, 0, 1, 1, 3, 2, 2, 2, 0, 3, 2, 2, 2, 1, 2, 0, 2,
#        3, 3, 3, 0, 2, 3, 0, 2, 0, 2, 0, 2, 2, 3, 2, 2, 2, 2, 2, 3, 3, 0,
#        3, 3, 3, 0, 2, 0, 2, 2, 0, 2, 2, 3, 0, 0, 0, 2, 3, 2, 0, 3, 0, 0,
#        2, 3, 0, 2, 2, 2, 3, 0, 2, 3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 2, 2, 0,
#        3, 3, 2, 2, 3, 0, 1, 1, 2, 0, 1, 3, 0, 1, 0, 2, 2, 2, 0, 3, 3, 3,
#        2, 2, 0, 2, 2, 2, 2, 3, 2, 2, 3, 1, 3, 2, 3, 0, 2, 3, 3, 2, 0, 3,
#        3, 0, 2, 3, 2, 3, 2, 2, 3, 3, 2, 3, 2, 2, 2, 0, 0, 3, 0, 2, 2, 3,
#        2, 2, 2, 2, 3, 1, 3, 2, 3, 3, 0, 3, 3, 3, 2, 2, 2, 2, 0, 0, 3, 2,
#        2, 3, 0, 2, 0, 2, 3, 3, 2, 0, 1, 0, 2, 3, 2, 3, 3, 1, 2, 3, 2, 3,
#        2, 3, 2, 2, 2, 0, 0, 3, 0, 0, 3, 0, 0, 3, 3, 0, 2, 0, 2, 3, 2, 3,
#        3, 2, 2, 3, 3, 3, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3, 3, 2,
#        2, 1, 1, 2, 2, 2, 2, 3, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 1, 3, 2,
#        3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 1, 1, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 1, 3, 3, 3, 3, 2,
#        2, 1, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 0, 3, 3, 2, 2, 2, 3, 3, 3, 3,
#        2, 2, 3, 3, 3, 3, 3, 3, 3, 2, 2, 3, 2, 3, 2, 2, 2, 2, 2, 2, 3, 3,
#        2, 2, 2, 2, 2, 3, 3, 2, 3, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3,
#        2, 2, 2, 2, 3, 2, 3, 3, 3, 0, 3, 2, 1, 2, 0, 2, 3, 3, 2, 2, 2, 0,
#        2, 0, 3, 0, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 3, 3, 2, 2, 3, 3, 1, 1,
#        3, 3, 3, 0, 2, 0, 3, 2, 2, 3, 3, 2, 0, 3, 3, 0, 3, 2, 0, 2, 3, 0,
#        2, 2, 0, 2, 0, 2, 0, 3, 0, 2, 3, 2, 2, 3, 2, 0, 2, 3, 2, 3, 2, 3,
#        3, 3, 2, 2, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 2, 2, 0, 0, 3, 3, 3, 3, 2])

# %%
le.fit_transform(df.job_title)
# Out:
# array([22, 41,  7, 47, 38, 12, 34, 22,  8, 33, 22, 22, 22, 32, 12, 12, 17,
#         7, 19, 33, 38, 47, 17,  5, 34, 25, 48, 17,  8, 40, 18,  7, 22, 48,
#        12, 17, 19, 38, 12, 38, 22, 18, 39, 17, 17, 36, 22, 17, 22, 17, 12,
#        12,  1, 17, 10, 46, 22, 22, 22, 22, 17, 17, 22, 22, 38, 22, 22, 21,
#        22, 22, 22, 22, 48,  5, 29, 22,  5,  0, 36, 12, 13, 17,  3, 38, 25,
#        17, 12, 13, 32, 12, 42, 19, 32, 33, 22,  9,  1, 28, 11, 11, 12, 17,
#         5, 12, 22, 12, 48, 17, 17, 17, 38, 24, 33,  1, 17, 41, 22, 20, 12,
#        17,  7, 45, 12,  3, 12, 46, 41, 22, 38, 34, 37, 22,  4, 10, 22, 12,
#        36, 36, 46, 22, 12, 21, 18, 22, 17, 38, 48, 17, 18,  9, 25, 22, 22,
#        22, 21, 20, 22,  4, 15, 38, 29, 30, 17, 19, 25, 23, 17, 25,  5, 16,
#        16, 17, 12, 46, 48, 18, 22, 22, 38, 22,  7, 22, 17, 27, 41, 17, 13,
#        19, 17, 38, 21, 38,  7, 21, 48, 22,  5, 38, 21, 19, 22, 39, 22, 48,
#        22, 22, 38, 17, 17, 15, 38, 48, 17,  7, 38, 45, 10, 22, 38, 15, 38,
#        22, 22, 22, 41, 46, 22, 22, 22, 12,  7, 36, 24, 12, 16, 30, 48, 22,
#        22, 17, 22, 12, 17, 22,  1, 17, 22, 17, 17, 44, 22, 22, 45, 22, 12,
#         6, 17, 46, 38, 25, 22, 12, 22, 38, 22, 33, 17, 17, 17, 17, 17, 10,
#        19, 38, 22, 22, 22,  1, 22,  8, 17, 48, 17, 49, 48, 21, 29, 22, 38,
#        17, 12, 12, 22, 22, 17, 17, 12, 12, 22, 22, 22, 22, 22, 22, 17, 12,
#        12, 12, 12, 17, 17, 22, 22, 17, 17, 22, 17, 22, 12, 17, 17, 17, 17,
#        22, 22, 12, 12, 12, 12, 12, 12, 12, 12, 12, 17, 17, 12, 17, 12, 12,
#        17, 17, 30, 30,  2, 17, 17, 22, 17, 12, 21, 21, 22, 22, 17, 17, 22,
#        22, 16, 16, 12, 12, 12, 12, 17, 22, 17, 12,  2, 22, 22, 38, 38, 26,
#        26, 33, 12, 17, 16, 16, 17, 17, 12, 12, 31, 17, 38, 12, 17, 38, 38,
#         1, 12, 12, 15, 15, 38, 17, 22, 22, 17, 17, 12, 12, 17, 17, 12, 17,
#        12, 22, 22, 22, 17, 17, 17, 17, 22, 20, 17, 41, 41, 21, 21, 22, 22,
#        17, 17, 17, 22, 12, 12, 12, 17, 17, 17, 17, 17, 17, 38, 38, 12, 12,
#        17, 17, 22, 17, 17, 17, 17, 36, 17, 37, 25, 38, 10, 43, 17, 35,  8,
#        22, 39, 28, 17, 22, 46, 17, 48, 22, 17, 22, 12, 12, 22, 22, 22, 22,
#        22, 38, 22, 22, 38, 38, 17, 17, 17, 38, 22, 22, 22,  4, 29, 44, 22,
#        37, 22, 41, 17, 22, 48, 22, 38, 29, 22, 38, 17, 22,  4, 48, 48,  3,
#        11,  8, 17, 38, 13, 22, 21, 17, 22,  3, 22, 10, 12, 14, 22,  3, 22,
#        12, 12, 12, 12, 12, 38, 38, 16, 16, 12, 17, 22, 22, 12, 12, 17, 17,
#        17, 17, 17, 17, 12, 17, 22, 22, 22, 22, 17, 17, 17, 17, 22, 22,  2,
#         2, 17, 17, 12, 17, 12, 12, 12, 22, 22, 22, 12, 12, 22, 22, 22, 12,
#        17, 17, 12, 12, 17, 17, 12, 12, 12, 22, 12, 12, 16, 16, 22, 22, 15,
#        15, 22, 12, 22, 22, 12, 12, 17, 17, 12, 12,  1])

# %%
for x in df.keys():
    print(f'the value of x is: {x}')
# Out:
# the value of x is: work_year
# the value of x is: experience_level
# the value of x is: employment_type
# the value of x is: job_title
# the value of x is: salary
# the value of x is: salary_currency
# the value of x is: salary_in_usd
# the value of x is: employee_residence
# the value of x is: remote_ratio
# the value of x is: company_location
# the value of x is: company_size

# %%
df.head()

# %%
for x in df.keys():
    if x in ['salary_in_usd', 'remote_ratio', 'work_year']:
        print("SKIIIIIP")
    else:
        df[f'{x}_enc'] = le.fit_transform(df[x])

# %%
for x in df.keys():
    if x == 'salary_in_usd':
        print("SKIIIIIP")
    else:
        df[f'{x}_enc'] = le.fit_transform(df[x])

# %%
df.head()

# %% [markdown]
# Exercise: find which columns should be scaled and do it.

# %%
# Hint, use:
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# Preparing to scale.
salary = df['salary_in_usd'].to_numpy()

# Reshaping.
salary = salary.reshape(-1,1)

# Creating a new column with the scaled bit
df['salary_in_usd_sc'] = MinMaxScaler().fit_transform(salary)

# %%
df.head()

# %%
df[['salary_in_usd_sc','salary_in_usd']]

# %% [markdown]
# Exercise: split the dataset into a training and test set.

# %%
# hint.
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, random_state=42)

# %%
df.keys()

# %%
X_train = train[['experience_level_enc', 'employment_type_enc', 'job_title_enc',
       'employee_residence_enc', 'company_location_enc',
       'company_size_enc']]
X_test = test[['experience_level_enc', 'employment_type_enc', 'job_title_enc',
       'employee_residence_enc', 'company_location_enc',
       'company_size_enc']]
y_train = train['salary_in_usd_sc']
y_test = test['salary_in_usd_sc']

# %%
type(X_train)

# %% [markdown]
# <h1>Decision Tree Regressor</h1>
# Now we will use the decision tree regressor
#
# [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)
#
# to try to estimate the values.

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Notice how similar it is with the classification trees.
DTR = DecisionTreeRegressor(max_depth=900,random_state=42)

DTR.fit(X_train,y_train)

y_pred = DTR.predict(X_test)

# %%
fig, ax = plt.subplots(1,1,figsize=(14,6))

ax.scatter(y_test,y_pred, s=10, label='Test')

ax.set_title(f'Data scientist salary prediction')

ax.legend()

# Adding an x=y line.
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

# %% [markdown]
# Exercise: calculate MAE and MSE.

# %%
# Hint.
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
ys_mae = mean_absolute_error(y_test,y_pred)
ys_mse = mean_squared_error(y_test,y_pred)

# %%
ys_mae

# %%
ys_mae = mean_absolute_error(y_test,y_pred)
ys_mse = mean_squared_error(y_test,y_pred)

fig, ax = plt.subplots(1,1,figsize=(14,6))

ax.scatter(y_test,y_pred, s=10, label='Test')

ax.set_title(f'Data scientist salary prediction \n MAE:{ys_mae:.3f}, MSE:{ys_mse:.3f}')

ax.legend()

# Adding an x=y line.
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

# %% [markdown]
# It is often useful to have an x=y line in to compare the results.

# %%
ys_mae = mean_absolute_error(y_test,y_pred)
ys_mse = mean_squared_error(y_test,y_pred)

fig, ax = plt.subplots(1,1,figsize=(14,6))

ax.scatter(y_test,y_pred, s=10, label='Test')

ax.set_title(f'Data scientist salary prediction \n MAE:{ys_mae:.2f}, MSE:{ys_mse:.2f}')

ax.legend()

# Adding an x=y line.
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

# %% [markdown]
# <h1>Random Forest Regressor</h1>
#
# Check the [Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Exercise: make a regression using the random forest regressor and plot your results.

# %%
RFR = RandomForestRegressor(n_estimators=1,max_depth=1, random_state=42)

RFR.fit(X_train,y_train)

y_pred = RFR.predict(X_test)

# %%
ys_mae = mean_absolute_error(y_test,y_pred)
ys_mse = mean_squared_error(y_test,y_pred)

fig, ax = plt.subplots(1,1,figsize=(14,6))

ax.scatter(y_test,y_pred, s=10, label='Test')

ax.set_title(f'Data scientist salary prediction \n MAE:{ys_mae:.2f}, MSE:{ys_mse:.2f}')

ax.legend()

# Adding an x=y line.
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

# %%
len(X_train)

# %%
len(X_test)

# %% [markdown]
# Exercise: try increasing the depth and observe how it changes

# %% [markdown]
# <h1>Support Vector Machines</h1>
#
# Link to the [Documentation](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html)

# %%
from sklearn.svm import SVR

# %% [markdown]
# Exercise: you know the drill.

# %%
rgr = SVR()

rgr.fit(X_train,y_train)

y_pred = rgr.predict(X_test)

# %%
ys_mae = mean_absolute_error(y_test,y_pred)
ys_mse = mean_squared_error(y_test,y_pred)

fig, ax = plt.subplots(1,1,figsize=(14,6))

ax.scatter(y_test,y_pred, s=10, label='Test')

ax.set_title(f'Data scientist salary prediction \n MAE:{ys_mae:.2f}, MSE:{ys_mse:.2f}')

ax.legend()

# Adding an x=y line.
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

# %% [markdown]
# <h1>Pipelining</h1>

# %%
from sklearn.pipeline import make_pipeline

# %%
 # We don't need to put the scaler there because we already took care of it.
regr = make_pipeline(SVR(C=1.0, epsilon=0.2))

# %%
regr.fit(X_train,y_train)

# %%
# Checking which parameters can be tunned.
regr.get_params()

# %%
parameteres = {'svr__C':[0.001,0.1,10,100,10e5], 'svr__gamma':[0.1,0.01]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
# defining the gridsearch.
grid = GridSearchCV(regr, 
                    param_grid=parameteres, 
                    cv=5)

# %%
grid.fit(X_train, y_train)
print("score = %3.2f" %(grid.score(X_test,y_test)))
print(grid.best_params_)

# %% [markdown]
# Final Exercise: improve the model accuracy. Feel free to use any methods and tools you see fit.
